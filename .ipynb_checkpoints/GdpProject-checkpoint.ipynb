# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# GRAPHICAL EXPLORATION & CLEANING

# %%
df = pd.read_csv("GDP_Origin.csv")

# %%
# Clean NaN / null values 

df = df.dropna()
df = df.drop_duplicates(keep='first')
df['LogFxRate'] = np.log(df['FxRate'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 555 entries, 9 to 726
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Cntry              555 non-null    object
#  1   LegEnvt            555 non-null    object
#  2   GeogZone1          555 non-null    object
#  3   IntalCCY           555 non-null    object
#  4   GdpGwth            555 non-null    float64
#  5   Year               555 non-null    float64
#  6   FxRate             555 non-null    float64
#  7   InflatioIndx       555 non-null    float64
#  8   OECDSTInterbkRate  555 non-null    float64
#  9   M3                 555 non-null    float64
#  10  LogFxRate          555 non-null    float64
# dtypes: float64(7), object(4)
# memory usage: 52.0+ KB

# %%
df.head()
# Out:
#         Cntry        LegEnvt       GeogZone1 IntalCCY  GdpGwth    Year  \
# 9   Australia  Common Wealth  Asia & Pacific      AUD    1.503  1990.0
# 10  Australia  Common Wealth  Asia & Pacific      AUD   -1.113  1991.0
# 11  Australia  Common Wealth  Asia & Pacific      AUD    2.652  1992.0
# 12  Australia  Common Wealth  Asia & Pacific      AUD    3.949  1993.0
# 13  Australia  Common Wealth  Asia & Pacific      AUD    4.888  1994.0
#
#      FxRate  InflatioIndx  OECDSTInterbkRate        M3  LogFxRate
# 9   1.29316     69.237722              12.58  17.49278   0.257089
# 10  1.31614     71.437180               8.50  18.44012   0.274703
# 11  1.45222     72.160289               5.75  19.06068   0.373093
# 12  1.47689     73.425731               4.75  20.11178   0.389939
# 13  1.28733     74.871949               7.05  21.65374   0.252570

# %%
df.dtypes
# Out:
# Cntry                 object
# LegEnvt               object
# GeogZone1             object
# IntalCCY              object
# GdpGwth              float64
# Year                 float64
# FxRate               float64
# InflatioIndx         float64
# OECDSTInterbkRate    float64
# M3                   float64
# LogFxRate            float64
# dtype: object

# %%
df.isnull().sum()
# No more null values

df.isna().sum()
# Same for NaN values
# Out:
# Cntry                0
# LegEnvt              0
# GeogZone1            0
# IntalCCY             0
# GdpGwth              0
# Year                 0
# FxRate               0
# InflatioIndx         0
# OECDSTInterbkRate    0
# M3                   0
# LogFxRate            0
# dtype: int64

# %%
sns.catplot(x='Year',y='GdpGwth', data=df)
plt.show()

# %%
sns.distplot(df['GdpGwth'], bins=10)
plt.show()

# %%
plt.figure(figsize=(7, 7))
df['Cntry'].value_counts().plot.bar()
plt.show()

# %%
ax = sns.lineplot(x='Year', y='GdpGwth', label='Gdp growth & year',
 data=df, ci=False)
plt.title('Relation between gdp growth & year', fontsize=14)
ax.set_xlabel('Year')
ax.set_ylabel('GDP Growth')
plt.show()

# %%
ax = sns.lineplot(x='Cntry', y='GdpGwth', label='Gdp growth & country',
 data=df, ci=False)
plt.title('Relation between gdp growth & country', fontsize=14)
ax.set_xlabel('Country')
ax.set_ylabel('GDP Growth')
plt.show()

# %%
ax = sns.swarmplot(data=df, x="Year", y="GdpGwth", hue="GeogZone1", size=5)
ax.set(ylabel="Gdp growth")
# Out:
# [Text(0, 0.5, 'Gdp growth')]

# %%
# DATA CALCUL :

# - Central tendency,
# - Dispersion measure of the data set
# - Minimum, Maximum,
# - Frequency table 25%, 50%, 75%
# - Count of observations

df.describe()
# Out:
#           GdpGwth         Year      FxRate  InflatioIndx  OECDSTInterbkRate  \
# count  564.000000   564.000000  564.000000    564.000000         564.000000
# mean     2.206449  2002.645390   16.563639     96.587422           3.796785
# std      2.572983     8.316035   47.480355     18.243799           3.886664
# min     -8.864000  1981.000000    0.499151     37.506556          -2.000000
# 25%      1.015750  1997.000000    0.772860     86.372000           0.645000
# 50%      2.402000  2003.500000    1.038550     98.138000           3.090000
# 75%      3.694500  2010.000000    5.581575    109.089250           5.232500
# max     10.778000  2015.000000  286.630000    149.084000          28.000000
#
#                M3
# count  564.000000
# mean    70.159943
# std     31.251935
# min      9.016603
# 25%     43.795695
# 50%     67.706670
# 75%    100.000000
# max    146.704000

# %%
pd.options.display.float_format = '{:,.0f}'.format
df.describe()
# Out:
#        GdpGwth  Year  FxRate  InflatioIndx  OECDSTInterbkRate  M3  LogFxRate
# count      555   555     555           555                555 555        555
# mean         2 2,003       5            97                  3  69          1
# std          2     7       9            15                  3  28          1
# min         -1 1,991       1            72                  0  30         -0
# 25%          1 1,997       1            86                  1  44         -0
# 50%          2 2,003       1            98                  3  67          0
# 75%          4 2,009       6           109                  5 100          2
# max          5 2,013      30           119                  8 107          3

# %%
import scipy.stats as sp
df_o = pd.DataFrame()
for col in df.columns:
     df_o[col] = sp.mstats.winsorize(df[col], limits=0.1, inplace=True)
        
df_o.describe()
# Out:
#        GdpGwth  Year  FxRate  InflatioIndx  OECDSTInterbkRate  M3  LogFxRate
# count      555   555     555           555                555 555        555
# mean         2 2,003       5            97                  3  69          1
# std          2     7       9            15                  3  28          1
# min         -1 1,991       1            72                  0  30         -0
# 25%          1 1,997       1            86                  1  44         -0
# 50%          2 2,003       1            98                  3  67          0
# 75%          4 2,009       6           109                  5 100          2
# max          5 2,013      30           119                  8 107          3

# %%
sns.swarmplot(data=df_o, x="Cntry", y="Year", hue="GdpGwth", size=5)

# %%
df_o.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e7566769ec0e> in <module>
# ----> 1 df_o.info()
#
# NameError: name 'df_o' is not defined

# %%
df_o['year_cat']= pd.cut(x=df['Year'], bins=[0, 1989, 1999, 2009, 2019],
 labels = ["1980-1989", "1990-1999",
 "2000-2009", "2010-2020"])

df_o.head(100)
# Out:
#       Cntry        LegEnvt       GeogZone1 IntalCCY  GdpGwth  Year  FxRate  \
# 0   Belgium  Common Wealth  Asia & Pacific      CAD        2 1,991       1
# 1   Belgium  Common Wealth  Asia & Pacific      CAD       -1 1,991       1
# 2   Belgium  Common Wealth  Asia & Pacific      CAD        3 1,992       1
# 3   Belgium  Common Wealth  Asia & Pacific      CAD        4 1,993       1
# 4   Belgium  Common Wealth  Asia & Pacific      CAD        5 1,994       1
# ..      ...            ...             ...      ...      ...   ...     ...
# 95   Canada  Common Wealth   North America      CAD        3 2,006       1
# 96   Canada  Common Wealth   North America      CAD        2 2,007       1
# 97   Canada  Common Wealth   North America      CAD        1 2,008       1
# 98   Canada  Common Wealth   North America      CAD       -1 2,009       1
# 99   Canada  Common Wealth   North America      CAD        3 2,010       1
#
#     InflatioIndx  OECDSTInterbkRate  M3  LogFxRate   year_cat
# 0             72                  8  30          0        NaN
# 1             72                  8  30          0        NaN
# 2             72                  6  30          0        NaN
# 3             73                  5  30          0        NaN
# 4             75                  7  30          0        NaN
# ..           ...                ...  ..        ...        ...
# 95           102                  4  74          0        NaN
# 96           104                  4  82         -0        NaN
# 97           107                  2  92          0  1990-1999
# 98           107                  0  95          0  1990-1999
# 99           109                  1 100          0  2010-2020
#
# [100 rows x 12 columns]

# %%
df_o['GdpGwth_cat']= pd.cut(x=df['GdpGwth'], bins=[-1, 0, 1, 2, 3, 4, 5, 6],
 labels = [-1, 0, 1, 2, 3, 4, 5])

df_o.head()
# Out:
#      Cntry        LegEnvt       GeogZone1 IntalCCY  GdpGwth  Year  FxRate  \
# 0  Belgium  Common Wealth  Asia & Pacific      CAD        2 1,991       1
# 1  Belgium  Common Wealth  Asia & Pacific      CAD       -1 1,991       1
# 2  Belgium  Common Wealth  Asia & Pacific      CAD        3 1,992       1
# 3  Belgium  Common Wealth  Asia & Pacific      CAD        4 1,993       1
# 4  Belgium  Common Wealth  Asia & Pacific      CAD        5 1,994       1
#
#    InflatioIndx  OECDSTInterbkRate  M3  LogFxRate year_cat GdpGwth_cat
# 0            72                  8  30          0      NaN         NaN
# 1            72                  8  30          0      NaN         NaN
# 2            72                  6  30          0      NaN         NaN
# 3            73                  5  30          0      NaN         NaN
# 4            75                  7  30          0      NaN         NaN

# %%
plt.figure(figsize=(15, 10))
sns.swarmplot(x="year_cat", y="InflatioIndx", hue='GdpGwth_cat', data=df_o)
plt.show()

# %%
sns.catplot(x="GdpGwth_cat", kind="count", data=df_o, height=5, aspect=2)
plt.show()

# %%
# Prediction & Machine learning
df_o.describe()
# Out:
#        GdpGwth  Year  FxRate  InflatioIndx  OECDSTInterbkRate  M3  LogFxRate
# count      555   555     555           555                555 555        555
# mean         2 2,003       5            97                  3  69          1
# std          2     7       9            15                  3  28          1
# min         -1 1,991       1            72                  0  30         -0
# 25%          1 1,997       1            86                  1  44         -0
# 50%          2 2,003       1            98                  3  67          0
# 75%          4 2,009       6           109                  5 100          2
# max          5 2,013      30           119                  8 107          3

# %%
X = df_o[['Year', 'InflatioIndx', 'LogFxRate', 'OECDSTInterbkRate', 'M3']]
y = df_o['GdpGwth']

from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X)

print('Intercept: \n', lr.intercept_)
print('Coefficients: \n', lr.coef_)
# Out:
# Intercept:
#  -264.07859207183554
# Coefficients:
#  [ 0.13517918 -0.02728864  0.02248854  0.14111011 -0.03211302]

# %%
import statsmodels.api as sm
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
predictionsFull = model.predict(X)
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                GdpGwth   R-squared:                       0.194
# Model:                            OLS   Adj. R-squared:                  0.187
# Method:                 Least Squares   F-statistic:                     26.45
# Date:                Sun, 29 Nov 2020   Prob (F-statistic):           5.64e-24
# Time:                        15:39:41   Log-Likelihood:                -1034.3
# No. Observations:                 555   AIC:                             2081.
# Df Residuals:                     549   BIC:                             2107.
# Df Model:                           5
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const              -264.0786     55.012     -4.800      0.000    -372.139    -156.018
# Year                  0.1352      0.028      4.842      0.000       0.080       0.190
# InflatioIndx         -0.0273      0.015     -1.841      0.066      -0.056       0.002
# LogFxRate             0.0225      0.055      0.406      0.685      -0.086       0.131
# OECDSTInterbkRate     0.1411      0.041      3.420      0.001       0.060       0.222
# M3                   -0.0321      0.008     -3.953      0.000      -0.048      -0.016
# ==============================================================================
# Omnibus:                       11.235   Durbin-Watson:                   1.128
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):                7.220
# Skew:                          -0.123   Prob(JB):                       0.0270
# Kurtosis:                       2.498   Cond. No.                     1.66e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.66e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
df_o.describe()
# Out:
#        GdpGwth  Year  FxRate  InflatioIndx  OECDSTInterbkRate  M3
# count      736   736     736           736                571 736
# mean         2 2,000       7            92                  4  65
# std          2     9      12            18                  6  33
# min         -1 1,986       1            61                  0  22
# 25%          1 1,992       1            77                  1  35
# 50%          2 2,001       1            94                  3  59
# 75%          4 2,008       6           107                  5 100
# max          5 2,013      36           118                100 117

# %%
with sns.axes_style ('white'):
    sns.jointplot('Year','GdpGwth', data=df_o,kind='reg')

# %%
import numpy as np
matrix = np.triu(df_o.corr())
sns.heatmap(df_o.corr(), annot= True, fmt='.1g',vmin=-1, vmax=1,center=0,cmap='coolwarm',
 square=True, mask=matrix)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (444, 6) (444,)
# (111, 6) (111,)

# %%
# Fit train
Lr_train = LinearRegression()
Lr_train.fit(X_train[['Year', 'InflatioIndx', 'LogFxRate', 'OECDSTInterbkRate', 'M3']], y_train)
y_predicted_train = Lr_train.predict(
 X_train[['Year', 'InflatioIndx', 'LogFxRate', 'OECDSTInterbkRate', 'M3']])

# %%
print('Intercept: \n', Lr_train.intercept_)
print('Coefficients: \n', Lr_train.coef_)
# Out:
# Intercept:
#  -193.32784083204623
# Coefficients:
#  [ 0.0989178  -0.01118193  0.0588039   0.16653327 -0.03004304]

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
R2_train = r2_score(y_train, y_predicted_train)
RMSE_Train = np.sqrt(mean_squared_error(y_train, y_predicted_train))
print ('R2 Train :', R2_train)
print ('RMSE Train :', RMSE_Train)
# Out:
# R2 Train : 0.206588010490673
# RMSE Train : 1.534263633821729

# %%
Lr_test = LinearRegression()
y_predicted_test = Lr_train.predict(
 X_test[['Year', 'InflatioIndx', 'LogFxRate', 'OECDSTInterbkRate', 'M3']])

# %%
Lr_test.fit(X_test[['Year', 'InflatioIndx', 'LogFxRate', 'OECDSTInterbkRate', 'M3']], y_test)
print('Intercept:\n', Lr_test.intercept_)
print('Coefficients:\n', Lr_test.coef_)
# Out:
# Intercept:
#  -595.352719789675
# Coefficients:
#  [ 0.30457471 -0.10383311 -0.10403454  0.08111696 -0.03333926]

# %%
R2_test = r2_score(y_test, y_predicted_test)
RMSE_Test = np.sqrt(mean_squared_error(y_test, y_predicted_test))
print ('R2 Train :', R2_test)
print ('RMSE Train :', RMSE_Test)
# Out:
# R2 Train : 0.09073806346361746
# RMSE Train : 1.6874610703403472
